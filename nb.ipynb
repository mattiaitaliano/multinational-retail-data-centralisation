# %%
import requests
import pandas as pd
dictionary ={'x-api-key':'yFBQbwXe9J3sd6zWVAMrK6lcxxr0q1lr2PT6DDMX'}

def list_number_of_store():
    stores = requests.get('https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/number_stores',headers=dictionary)
    data = stores.json()
    return data["number_stores"]
ciao = list_number_of_store()
ciao
# Out:
# 451

# %%
n_of_stores = list_number_of_store()
stores_list = []
for store_number in range(0, n_of_stores):
    stores_list.append(requests.get('https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/'+str(store_number), headers=dictionary).json())
df = pd.json_normalize(stores_list)
df
# Out:
#      index                                            address   longitude  \
# 0      0.0                                                N/A         N/A
# 1      1.0  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...    51.62907
# 2      2.0        Heckerstraße 4/5\n50491 Säckingen, Landshut    48.52961
# 3      3.0  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury       51.26
# 4      4.0  Studio 6\nStephen landing\nSouth Simon\nB77 2W...     53.0233
# ..     ...                                                ...         ...
# 447  447.0                                         K0ODETRLS3  K8CXLZDP07
# 448  448.0  Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High...    51.62907
# 449  449.0               Baumplatz 6\n80114 Kötzting, Bretten    49.03685
# 450  450.0  Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, ...    50.64336
# 451    NaN                                                NaN         NaN
#
#             lat      locality    store_code staff_numbers opening_date  \
# ...
